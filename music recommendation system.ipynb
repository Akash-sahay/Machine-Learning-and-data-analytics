# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Akash Sahay\\Desktop\\machine_learning'

# %%
os.chdir('C:\\Users\\Akash Sahay\\Downloads\\PRJ Music Recommendation System-20221008T130124Z-001\\PRJ Music Recommendation System\\')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Akash Sahay\\Downloads\\PRJ Music Recommendation System-20221008T130124Z-001\\PRJ Music Recommendation System'

# %%
import Recommenders as Recommenders

# %%
song_df_1 = pd.read_csv('triplets_file.csv')
print (song_df_1.shape)
print (song_df_1.head())
# Out:
# (2000000, 3)
#                                     user_id             song_id  listen_count
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1

# %%
song_df_2 = pd.read_csv('song_data.csv')
print (song_df_2.shape)
display  (song_df_2.head())
# Out:
# (1000000, 5)
#               song_id              title  \
# 0  SOQMMHC12AB0180CB8       Silent Night
# 1  SOVFVAK12A8C1350D9        Tanssi vaan
# 2  SOGTUKN12AB017F4F1  No One Could Ever
# 3  SOBNYVR12A8C13558C      Si Vos Querés
# 4  SOHSBXH12A8C13B0DF   Tangle Of Aspens
#
#                                 release       artist_name  year
# 0                 Monster Ballads X-Mas  Faster Pussy cat  2003
# 1                           Karkuteillä  Karkkiautomaatti  1995
# 2                                Butter    Hudson Mohawke  2006
# 3                               De Culo       Yerba Brava  2003
# 4  Rene Ablaze Presents Winter Sessions        Der Mystic     0

# %%
song_df = pd.merge(song_df_1, song_df_2.drop_duplicates(['song_id']), on='song_id', how='left')
display (song_df.shape)
display (song_df.head())
# Out:
# (2000000, 7)
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title                        release    artist_name  year
# 0         The Cove             Thicker Than Water   Jack Johnson     0
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976
# 2         Stronger                     Graduation     Kanye West  2007
# 3   Constellations              In Between Dreams   Jack Johnson  2005
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999

# %%
print(len(song_df_1), len(song_df_2))
# Out:
# 2000000 1000000

# %%
len(song_df)
# Out:
# 2000000

# %%
song_df = song_df.head(40000)
song_df.shape
# Out:
# (40000, 7)

# %%
song_df['song'] = song_df['title']+' - '+song_df['artist_name']
song_df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title                        release    artist_name  year  \
# 0         The Cove             Thicker Than Water   Jack Johnson     0
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976
# 2         Stronger                     Graduation     Kanye West  2007
# 3   Constellations              In Between Dreams   Jack Johnson  2005
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999
#
#                               song
# 0          The Cove - Jack Johnson
# 1  Entre Dos Aguas - Paco De Lucia
# 2            Stronger - Kanye West
# 3    Constellations - Jack Johnson
# 4      Learn To Fly - Foo Fighters

# %%
song_grouped = song_df.groupby(['song']).agg({'listen_count':'count'}).reset_index()
song_grouped.head()
# Out:
#                               song  listen_count
# 0         #40 - DAVE MATTHEWS BAND             4
# 1              & Down - Boys Noize            10
# 2        ' Cello Song - Nick Drake             3
# 3      '97 Bonnie & Clyde - Eminem             3
# 4  'Round Midnight - Amy Winehouse             3

# %%
grouped_sum = song_grouped['listen_count'].sum()
grouped_sum
# Out:
# 40000

# %%
song_grouped['percentage'] = (song_grouped['listen_count'] / grouped_sum ) * 100
song_grouped.sort_values(['listen_count', 'song'], ascending=[0,1])
# Out:
#                                                    song  listen_count  \
# 6399                           Sehr kosmisch - Harmonia           155
# 1858  Dog Days Are Over (Radio Edit) - Florence + Th...           144
# 8130                                       Undo - Björk           139
# 6081                            Revelry - Kings Of Leon           132
# 8849                     You're The One - Dwight Yoakam           132
# ...                                                 ...           ...
# 8883                    Your Time Has Come - Audioslave             1
# 8899                                Zwitter - Rammstein             1
# 8903                                clouding - Four Tet             1
# 8904                              high fives - Four Tet             1
# 8913                               the Love Song - K-OS             1
#
#       percentage
# 6399      0.3875
# 1858      0.3600
# 8130      0.3475
# 6081      0.3300
# 8849      0.3300
# ...          ...
# 8883      0.0025
# 8899      0.0025
# 8903      0.0025
# 8904      0.0025
# 8913      0.0025
#
# [8917 rows x 3 columns]

# %%
pr = Recommenders.popularity_recommender_py()
pr.create(song_df, 'user_id', 'song')

# %%
pr.recommend(song_df['user_id'][5])
# Out:
#                                        user_id  \
# 6399  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 1858  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 8130  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 6081  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 8849  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 6389  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 3238  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 2427  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 7921  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 3127  b80344d063b5ccb3212f76538f3d9e43d87dca9e
#
#                                                    song  score  Rank
# 6399                           Sehr kosmisch - Harmonia    155   1.0
# 1858  Dog Days Are Over (Radio Edit) - Florence + Th...    144   2.0
# 8130                                       Undo - Björk    139   3.0
# 6081                            Revelry - Kings Of Leon    132   4.0
# 8849                     You're The One - Dwight Yoakam    132   5.0
# 6389                              Secrets - OneRepublic    126   6.0
# 3238  Horn Concerto No. 4 in E flat K495: II. Romanc...    105   7.0
# 2427                     Fireflies - Charttraxx Karaoke    102   8.0
# 7921                                 Tive Sim - Cartola     94   9.0
# 3127                           Hey_ Soul Sister - Train     87  10.0

# %%
pr.recommend(song_df['user_id'][100])
# Out:
#                                        user_id  \
# 6399  e006b1a48f466bf59feefed32bec6494495a4436
# 1858  e006b1a48f466bf59feefed32bec6494495a4436
# 8130  e006b1a48f466bf59feefed32bec6494495a4436
# 6081  e006b1a48f466bf59feefed32bec6494495a4436
# 8849  e006b1a48f466bf59feefed32bec6494495a4436
# 6389  e006b1a48f466bf59feefed32bec6494495a4436
# 3238  e006b1a48f466bf59feefed32bec6494495a4436
# 2427  e006b1a48f466bf59feefed32bec6494495a4436
# 7921  e006b1a48f466bf59feefed32bec6494495a4436
# 3127  e006b1a48f466bf59feefed32bec6494495a4436
#
#                                                    song  score  Rank
# 6399                           Sehr kosmisch - Harmonia    155   1.0
# 1858  Dog Days Are Over (Radio Edit) - Florence + Th...    144   2.0
# 8130                                       Undo - Björk    139   3.0
# 6081                            Revelry - Kings Of Leon    132   4.0
# 8849                     You're The One - Dwight Yoakam    132   5.0
# 6389                              Secrets - OneRepublic    126   6.0
# 3238  Horn Concerto No. 4 in E flat K495: II. Romanc...    105   7.0
# 2427                     Fireflies - Charttraxx Karaoke    102   8.0
# 7921                                 Tive Sim - Cartola     94   9.0
# 3127                           Hey_ Soul Sister - Train     87  10.0

# %%
ir = Recommenders.item_similarity_recommender_py()
ir.create(song_df, 'user_id', 'song')

# %%
user_items = ir.get_user_items(song_df['user_id'][5])
# display user songs history
for user_item in user_items:
    print(user_item)
# Out:
# The Cove - Jack Johnson
# Entre Dos Aguas - Paco De Lucia
# Stronger - Kanye West
# Constellations - Jack Johnson
# Learn To Fly - Foo Fighters
# Apuesta Por El Rock 'N' Roll - Héroes del Silencio
# Paper Gangsta - Lady GaGa
# Stacked Actors - Foo Fighters
# Sehr kosmisch - Harmonia
# Heaven's gonna burn your eyes - Thievery Corporation feat. Emiliana Torrini
# Let It Be Sung - Jack Johnson / Matt Costa / Zach Gill / Dan Lebowitz / Steve Adams
# I'll Be Missing You (Featuring Faith Evans & 112)(Album Version) - Puff Daddy
# Love Shack - The B-52's
# Clarity - John Mayer
# I?'m A Steady Rollin? Man - Robert Johnson
# The Old Saloon - The Lonely Island
# Behind The Sea [Live In Chicago] - Panic At The Disco
# Champion - Kanye West
# Breakout - Foo Fighters
# Ragged Wood - Fleet Foxes
# Mykonos - Fleet Foxes
# Country Road - Jack Johnson / Paula Fuga
# Oh No - Andrew Bird
# Love Song For No One - John Mayer
# Jewels And Gold - Angus & Julia Stone
# Warning - Incubus
# 83 - John Mayer
# Neon - John Mayer
# The Middle - Jimmy Eat World
# High and dry - Jorge Drexler
# All That We Perceive - Thievery Corporation
# The Christmas Song  (LP Version) - King Curtis
# Our Swords (Soundtrack Version) - Band Of Horses
# Are You In? - Incubus
# Drive - Incubus
# Generator - Foo Fighters
# Come Back To Bed - John Mayer
# He Doesn't Know Why - Fleet Foxes
# Trani - Kings Of Leon
# Bigger Isn't Better - The String Cheese Incident
# Sun Giant - Fleet Foxes
# City Love - John Mayer
# Right Back - Sublime
# Moonshine - Jack Johnson
# Holes To Heaven - Jack Johnson

# %%
user_items = ir.get_user_items(song_df['user_id'][100])
# display user songs history
for user_item in user_items:
    print(user_item)
# Out:
# Undo - Björk
# Dog Days Are Over (Radio Edit) - Florence + The Machine
# High Life - Daft Punk
# You're The One - Dwight Yoakam
# Where Did You Sleep Last Night - Nirvana
# Come As You Are - Nirvana
# Hey_ Soul Sister - Train
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile) - Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner
# Rhyme & Reason - DAVE MATTHEWS BAND
# Sehr kosmisch - Harmonia
# Someone Else's Arms - Mae
# Cry For Help (Album Version) - Shinedown
# Lady In Black - Ensiferum
# For You (Amended/Radio Edit LP) - Staind
# Fireflies - Charttraxx Karaoke
# Secrets - OneRepublic
# Esta Es Para Hacerte Féliz - Jorge Gonzalez
# Revelry - Kings Of Leon
# Marry Me - Train
# OMG - Usher featuring will.i.am
# Drop The World - Lil Wayne / Eminem
# Ain't Misbehavin - Sam Cooke
# Blow Me Away - Breaking Benjamin
# Use Somebody - Kings Of Leon
# Corn Bread - DAVE MATTHEWS BAND

# %%
ir.recommend(song_df['user_id'][5])
# Out:
# No. of unique songs for the user: 45
# no. of unique songs in the training set: 8917
# Non zero values in cooccurence_matrix :23086
#                                     user_id                             song  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  Better That We Break - Maroon 5
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e         Questions - Jack Johnson
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e        Wrong Turn - Jack Johnson
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e   Ghost Dream - Hymie's Basement
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e       Great Indoors - John Mayer
# 5  b80344d063b5ccb3212f76538f3d9e43d87dca9e       Baby I Want You - Amos Lee
# 6  b80344d063b5ccb3212f76538f3d9e43d87dca9e      Wasting Time - Jack Johnson
# 7  b80344d063b5ccb3212f76538f3d9e43d87dca9e  The Sharing Song - Jack Johnson
# 8  b80344d063b5ccb3212f76538f3d9e43d87dca9e           Better Days - Amos Lee
# 9  b80344d063b5ccb3212f76538f3d9e43d87dca9e                Listen - Amos Lee
#
#       score  rank
# 0  0.045611     1
# 1  0.042698     2
# 2  0.042664     3
# 3  0.041993     4
# 4  0.041761     5
# 5  0.040724     6
# 6  0.040324     7
# 7  0.040324     8
# 8  0.040324     9
# 9  0.040324    10

# %%
ir.recommend(song_df['user_id'][100])
# Out:
# No. of unique songs for the user: 25
# no. of unique songs in the training set: 8917
# Non zero values in cooccurence_matrix :39526
#                                     user_id  \
# 0  e006b1a48f466bf59feefed32bec6494495a4436
# 1  e006b1a48f466bf59feefed32bec6494495a4436
# 2  e006b1a48f466bf59feefed32bec6494495a4436
# 3  e006b1a48f466bf59feefed32bec6494495a4436
# 4  e006b1a48f466bf59feefed32bec6494495a4436
# 5  e006b1a48f466bf59feefed32bec6494495a4436
# 6  e006b1a48f466bf59feefed32bec6494495a4436
# 7  e006b1a48f466bf59feefed32bec6494495a4436
# 8  e006b1a48f466bf59feefed32bec6494495a4436
# 9  e006b1a48f466bf59feefed32bec6494495a4436
#
#                                                 song     score  rank
# 0  Lucky (Album Version) - Jason Mraz & Colbie Ca...  0.097468     1
# 1  Pursuit Of Happiness (nightmare) - Kid Cudi / ...  0.096825     2
# 2                    Heartbreak Warfare - John Mayer  0.091462     3
# 3                   Somebody To Love - Justin Bieber  0.087520     4
# 4                           The Scientist - Coldplay  0.082741     5
# 5                          Love Story - Taylor Swift  0.082538     6
# 6                              Bulletproof - La Roux  0.081106     7
# 7  Bleed It Out [Live At Milton Keynes] - Linkin ...  0.079579     8
# 8                              Alejandro - Lady GaGa  0.078467     9
# 9      The Only Exception (Album Version) - Paramore  0.076672    10

# %%
ir.get_similar_items(['Secrets-One Republic','Love Story-Taylor Swift'])
# Out:
# no. of unique songs in the training set: 8917
# Non zero values in cooccurence_matrix :0
#   user_id                                               song  score  rank
# 0                                Who By Fire - Leonard Cohen    0.0     1
# 1                                You Made Me Like It - 1990s    0.0     2
# 2              Uninvited (Album Version) - Alanis Morissette    0.0     3
# 3                            Don´t Leave Me Now - Amparanoia    0.0     4
# 4                                      Kiksu - Kyau & Albert    0.0     5
# 5                                    Kalopsia - The Blizzard    0.0     6
# 6                                What I Want - Dead Or Alive    0.0     7
# 7                                             Ashes - Pepper    0.0     8
# 8          G.O.D. (Gaining One's Definition) Featuring Ce...    0.0     9
# 9                          The More I See You - June Christy    0.0    10

# %%
ir.get_similar_items(['Love Story'])
# Out:
# no. of unique songs in the training set: 8917
# Non zero values in cooccurence_matrix :0
#   user_id                                               song  score  rank
# 0                                Who By Fire - Leonard Cohen    0.0     1
# 1                                You Made Me Like It - 1990s    0.0     2
# 2              Uninvited (Album Version) - Alanis Morissette    0.0     3
# 3                            Don´t Leave Me Now - Amparanoia    0.0     4
# 4                                      Kiksu - Kyau & Albert    0.0     5
# 5                                    Kalopsia - The Blizzard    0.0     6
# 6                                What I Want - Dead Or Alive    0.0     7
# 7                                             Ashes - Pepper    0.0     8
# 8          G.O.D. (Gaining One's Definition) Featuring Ce...    0.0     9
# 9                          The More I See You - June Christy    0.0    10
